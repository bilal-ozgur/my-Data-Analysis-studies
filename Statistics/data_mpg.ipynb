# %%
#pip install seaborn
#pip install matplotlib
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting numpy!=1.24.0,>=1.17
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
# Collecting pandas>=0.25
#   Using cached pandas-2.0.1-cp311-cp311-win_amd64.whl (10.6 MB)
# Collecting matplotlib!=3.6.1,>=3.1
#   Using cached matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#      -------------------------------------- 55.4/55.4 kB 322.5 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\bilal\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.2 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.3/98.3 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bilal\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      -------------------------------------- 502.3/502.3 kB 1.4 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ------------------------------------ 341.8/341.8 kB 517.3 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\bilal\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.3 kiwisolver-1.4.4 matplotlib-3.7.1 numpy-1.24.3 pandas-2.0.1 pillow-9.5.0 pyparsing-3.0.9 pytz-2023.3 seaborn-0.12.2 tzdata-2023.3
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("mpg")

# %%
df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration
# 154  15.0          6         250.0        72.0    3432          21.0  \
# 99   18.0          6         232.0       100.0    2945          16.0
# 108  20.0          4          97.0        88.0    2279          19.0
# 239  30.0          4          97.0        67.0    1985          16.4
# 321  32.2          4         108.0        75.0    2265          15.2
#
#      model_year origin             name
# 154          75    usa  mercury monarch
# 99           73    usa       amc hornet
# 108          73  japan    toyota carina
# 239          77  japan        subaru dl
# 321          80  japan   toyota corolla

# %%
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df.origin.value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
sns.countplot(x="origin", data=df);

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = df.origin.value_counts().index
sizes = df.origin.value_counts().values
explode = ( 0, 0.2, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots(figsize=(7,7))

ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=110)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df.cylinders.value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
sns.countplot(x="cylinders", data=df);

# %%
sns.barplot(x="origin", y ="weight", data = df);
#or df.groupby("origin").weight.mean().plot.bar()

# %%
sns.barplot(x="cylinders", y ="weight", data = df);
#here shows avg mpg values in different continents

# %%
sns.histplot(x="weight", data =df);

# %%
sns.histplot(x="horsepower", data =df);

# %%
sns.boxplot(x="horsepower", data = df);

# %%
x=np.random.normal(0,2,10000000)
plt.hist(x,bins=100);

# %%
shape, scale = 2, 2
s=np.random.gamma(shape,scale, 100000)

# %%
plt.hist(s, bins=100);
